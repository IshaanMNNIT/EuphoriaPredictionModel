# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import roc_auc_score, make_scorer, accuracy_score
from sklearn.ensemble import RandomForestClassifier, StackingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from scipy.stats import mode

# %%
df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %%
arr = df.values.astype(float)
finite_mask = np.isfinite(arr)
col_min = np.nanmin(np.where(finite_mask, arr, np.nan), axis=0)
col_max = np.nanmax(np.where(finite_mask, arr, np.nan), axis=0)
arr[arr == -np.inf] = col_min[np.where(arr == -np.inf)[1]]
arr[arr == np.inf]  = col_max[np.where(arr == np.inf)[1]]
df_fixed = pd.DataFrame(arr, columns=df.columns)
df = df_fixed

# %%
arr = test_df.values.astype(float)
finite_mask = np.isfinite(arr)
col_min = np.nanmin(np.where(finite_mask, arr, np.nan), axis=0)
col_max = np.nanmax(np.where(finite_mask, arr, np.nan), axis=0)
arr[arr == -np.inf] = col_min[np.where(arr == -np.inf)[1]]
arr[arr == np.inf]  = col_max[np.where(arr == np.inf)[1]]
test_df_fixed = pd.DataFrame(arr, columns=test_df.columns)
test_df = test_df_fixed

# %%
cols = df.columnscols = df.columns
test_cols = test_df.columns
imputer = SimpleImputer(strategy='mean')
df[cols] = imputer.fit_transform(df[cols])
test_df[test_cols] = imputer.fit_transform(test_df[test_cols])
test_cols = test_df.columns
imputer = SimpleImputer(strategy='mean')
df[cols] = imputer.fit_transform(df[cols])
test_df[test_cols] = imputer.fit_transform(test_df[test_cols])
# Out:
# C:\Users\Ishaan Singh\AppData\Local\Temp\ipykernel_3120\2219958899.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   cols = df.columnscols = df.columns

# %%
df = df.drop(columns = 'id')
test_id = test_df['id']
test_df = test_df.drop(columns = 'id')

# %%
Y = df['Y']
X = df.drop(columns = 'Y')

# %%
cols = X.columns
test_cols = test_df.columns
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
X = pd.DataFrame(X, columns=cols)
test_df = scaler.fit_transform(test_df)
test_df = pd.DataFrame(test_df, columns=test_cols)

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

oof_preds = np.zeros(len(X))
test_preds = []  # if you later have test data

for fold, (train_idx, val_idx) in enumerate(skf.split(X, Y), 1):
    print(f"\n----- Fold {fold} -----")
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = Y.iloc[train_idx], Y.iloc[val_idx]


    model = CatBoostClassifier(
        iterations=5000,
        learning_rate=0.01,
        depth=6,
        eval_metric="AUC",
        random_seed=42,
        verbose=200,
        class_weights=[1, (len(Y)-sum(Y))/sum(Y)],
        use_best_model=True
        )
    model.fit(X_train, y_train, eval_set=(X_val, y_val), use_best_model=True)

    # Out-of-fold predictions
    oof_preds[val_idx] = model.predict_proba(X_val)[:, 1]

    # Evaluate
    acc = accuracy_score(y_val, (oof_preds[val_idx] > 0.5).astype(int))
    auc = roc_auc_score(y_val, oof_preds[val_idx])
    print(f"Fold {fold} Accuracy: {acc:.4f}, ROC AUC: {auc:.4f}")

# Overall performance
final_acc = accuracy_score(Y, (oof_preds > 0.5).astype(int))
final_auc = roc_auc_score(Y, oof_preds)

print(f"\nOverall Accuracy: {final_acc:.4f}")
print(f"Overall ROC AUC:  {final_auc:.4f}")
# Out:
# ----- Fold 1 -----
# 0:	test: 0.7755322	best: 0.7755322 (0)	total: 172ms	remaining: 14m 20s
# 200:	test: 0.7915561	best: 0.7915561 (200)	total: 9.25s	remaining: 3m 40s
# 400:	test: 0.7931822	best: 0.7931822 (400)	total: 18.4s	remaining: 3m 30s
# 600:	test: 0.7935286	best: 0.7935349 (595)	total: 28.3s	remaining: 3m 27s
# 800:	test: 0.7937426	best: 0.7937426 (800)	total: 37.3s	remaining: 3m 15s
# 1000:	test: 0.7939969	best: 0.7939988 (999)	total: 50.7s	remaining: 3m 22s
# 1200:	test: 0.7939532	best: 0.7940559 (1069)	total: 1m 3s	remaining: 3m 20s
# 1400:	test: 0.7940797	best: 0.7940816 (1381)	total: 1m 13s	remaining: 3m 8s
# 1600:	test: 0.7941215	best: 0.7941921 (1501)	total: 1m 22s	remaining: 2m 55s
# 1800:	test: 0.7940272	best: 0.7941921 (1501)	total: 1m 30s	remaining: 2m 40s
# 2000:	test: 0.7939501	best: 0.7941921 (1501)	total: 1m 38s	remaining: 2m 27s
# 2200:	test: 0.7936386	best: 0.7941921 (1501)	total: 1m 46s	remaining: 2m 14s
# 2400:	test: 0.7936287	best: 0.7941921 (1501)	total: 1m 53s	remaining: 2m 3s
# 2600:	test: 0.7934879	best: 0.7941921 (1501)	total: 2m 1s	remaining: 1m 52s
# 2800:	test: 0.7934292	best: 0.7941921 (1501)	total: 2m 10s	remaining: 1m 42s
# 3000:	test: 0.7930709	best: 0.7941921 (1501)	total: 2m 18s	remaining: 1m 32s
# 3200:	test: 0.7928201	best: 0.7941921 (1501)	total: 2m 25s	remaining: 1m 21s
# 3400:	test: 0.7927050	best: 0.7941921 (1501)	total: 2m 33s	remaining: 1m 12s
# 3600:	test: 0.7925702	best: 0.7941921 (1501)	total: 2m 40s	remaining: 1m 2s
# 3800:	test: 0.7924150	best: 0.7941921 (1501)	total: 2m 48s	remaining: 53.2s
# 4000:	test: 0.7920331	best: 0.7941921 (1501)	total: 2m 56s	remaining: 44s
# 4200:	test: 0.7917704	best: 0.7941921 (1501)	total: 3m 3s	remaining: 34.9s
# 4400:	test: 0.7916284	best: 0.7941921 (1501)	total: 3m 10s	remaining: 26s
# 4600:	test: 0.7914492	best: 0.7941921 (1501)	total: 3m 18s	remaining: 17.2s
# 4800:	test: 0.7912563	best: 0.7941921 (1501)	total: 3m 25s	remaining: 8.54s
# 4999:	test: 0.7910785	best: 0.7941921 (1501)	total: 3m 33s	remaining: 0us
#
# bestTest = 0.7941920848
# bestIteration = 1501
#
# Shrink model to first 1502 iterations.
# Fold 1 Accuracy: 0.7538, ROC AUC: 0.7942
#
# ----- Fold 2 -----
# 0:	test: 0.7703057	best: 0.7703057 (0)	total: 27.1ms	remaining: 2m 15s
# 200:	test: 0.7877516	best: 0.7877516 (200)	total: 7.74s	remaining: 3m 4s
# 400:	test: 0.7891042	best: 0.7891042 (400)	total: 15.2s	remaining: 2m 54s
# 600:	test: 0.7897568	best: 0.7897568 (600)	total: 22.7s	remaining: 2m 46s
# 800:	test: 0.7900105	best: 0.7900105 (800)	total: 30.1s	remaining: 2m 37s
# 1000:	test: 0.7902184	best: 0.7902238 (998)	total: 38.2s	remaining: 2m 32s
# 1200:	test: 0.7906660	best: 0.7906730 (1199)	total: 46.1s	remaining: 2m 25s
# 1400:	test: 0.7909639	best: 0.7910004 (1345)	total: 53.6s	remaining: 2m 17s
# 1600:	test: 0.7909793	best: 0.7910581 (1521)	total: 1m 1s	remaining: 2m 9s
# 1800:	test: 0.7909738	best: 0.7910581 (1521)	total: 1m 8s	remaining: 2m 1s
# 2000:	test: 0.7907664	best: 0.7910581 (1521)	total: 1m 15s	remaining: 1m 53s
# 2200:	test: 0.7907282	best: 0.7910581 (1521)	total: 1m 24s	remaining: 1m 46s
# 2400:	test: 0.7905341	best: 0.7910581 (1521)	total: 1m 31s	remaining: 1m 38s
# 2600:	test: 0.7903948	best: 0.7910581 (1521)	total: 1m 38s	remaining: 1m 31s
# 2800:	test: 0.7902375	best: 0.7910581 (1521)	total: 1m 46s	remaining: 1m 23s
# 3000:	test: 0.7899490	best: 0.7910581 (1521)	total: 1m 53s	remaining: 1m 15s
# 3200:	test: 0.7898672	best: 0.7910581 (1521)	total: 2m 1s	remaining: 1m 8s
# 3400:	test: 0.7896777	best: 0.7910581 (1521)	total: 2m 8s	remaining: 1m
# 3600:	test: 0.7893811	best: 0.7910581 (1521)	total: 2m 16s	remaining: 53.1s
# 3800:	test: 0.7892144	best: 0.7910581 (1521)	total: 2m 24s	remaining: 45.6s
# 4000:	test: 0.7889894	best: 0.7910581 (1521)	total: 2m 32s	remaining: 38s
# 4200:	test: 0.7887782	best: 0.7910581 (1521)	total: 2m 40s	remaining: 30.5s
# 4400:	test: 0.7886442	best: 0.7910581 (1521)	total: 2m 48s	remaining: 22.9s
# 4600:	test: 0.7884487	best: 0.7910581 (1521)	total: 2m 56s	remaining: 15.3s
# 4800:	test: 0.7882830	best: 0.7910581 (1521)	total: 3m 4s	remaining: 7.65s
# 4999:	test: 0.7881406	best: 0.7910581 (1521)	total: 3m 12s	remaining: 0us
#
# bestTest = 0.7910580586
# bestIteration = 1521
#
# Shrink model to first 1522 iterations.
# Fold 2 Accuracy: 0.7554, ROC AUC: 0.7911
#
# ----- Fold 3 -----
# 0:	test: 0.7726990	best: 0.7726990 (0)	total: 24.6ms	remaining: 2m 2s
# 200:	test: 0.7914926	best: 0.7914926 (200)	total: 7.85s	remaining: 3m 7s
# 400:	test: 0.7926611	best: 0.7926611 (400)	total: 15.8s	remaining: 3m 1s
# 600:	test: 0.7931605	best: 0.7931605 (600)	total: 23.3s	remaining: 2m 50s
# 800:	test: 0.7935003	best: 0.7935026 (793)	total: 30.8s	remaining: 2m 41s
# 1000:	test: 0.7938446	best: 0.7938446 (1000)	total: 38.4s	remaining: 2m 33s
# 1200:	test: 0.7943099	best: 0.7943099 (1200)	total: 46s	remaining: 2m 25s
# 1400:	test: 0.7944621	best: 0.7944829 (1334)	total: 54.3s	remaining: 2m 19s
# 1600:	test: 0.7944290	best: 0.7946008 (1479)	total: 1m 2s	remaining: 2m 11s
# 1800:	test: 0.7944025	best: 0.7946008 (1479)	total: 1m 10s	remaining: 2m 4s
# 2000:	test: 0.7941897	best: 0.7946008 (1479)	total: 1m 18s	remaining: 1m 57s
# 2200:	test: 0.7939601	best: 0.7946008 (1479)	total: 1m 26s	remaining: 1m 49s
# 4000:	test: 0.7874089	best: 0.7899484 (1230)	total: 2m 39s	remaining: 39.9s
# 4200:	test: 0.7872678	best: 0.7899484 (1230)	total: 2m 46s	remaining: 31.8s
# 4400:	test: 0.7871717	best: 0.7899484 (1230)	total: 2m 54s	remaining: 23.8s
# 4600:	test: 0.7869819	best: 0.7899484 (1230)	total: 3m 1s	remaining: 15.8s
# 4800:	test: 0.7868327	best: 0.7899484 (1230)	total: 3m 9s	remaining: 7.84s
# 4999:	test: 0.7866014	best: 0.7899484 (1230)	total: 3m 16s	remaining: 0us
#
# bestTest = 0.7899483582
# bestIteration = 1230
#
# Shrink model to first 1231 iterations.
# Fold 5 Accuracy: 0.7511, ROC AUC: 0.7899
#
# Overall Accuracy: 0.7528
# Overall ROC AUC:  0.7930

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

oof_preds = np.zeros(len(X))
test_preds = np.zeros(len(test_df))

for fold, (train_idx, val_idx) in enumerate(skf.split(X, Y), 1):
    print(f"\n----- Fold {fold} -----")

    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = Y.iloc[train_idx], Y.iloc[val_idx]

    model = CatBoostClassifier(
        iterations=5000,
        learning_rate=0.05,
        depth=6,
        eval_metric="AUC",
        random_seed=42,
        verbose=200,
        class_weights=[1, (len(Y)-sum(Y))/sum(Y)],
        use_best_model=True
        )
    model.fit(X_train, y_train, eval_set=(X_val, y_val), use_best_model=True)

    # OOF validation predictions (probabilities)
    oof_preds[val_idx] = model.predict_proba(X_val)[:, 1]

    # Average test predictions across folds (probabilities)
    test_preds += model.predict_proba(test_df)[:, 1] / skf.n_splits

    # Metrics for this fold
    acc = accuracy_score(y_val, (oof_preds[val_idx] > 0.5).astype(int))
    auc = roc_auc_score(y_val, oof_preds[val_idx])
    print(f"Fold {fold} Accuracy: {acc:.4f}, ROC AUC: {auc:.4f}")

# Overall metrics
final_acc = accuracy_score(Y, (oof_preds > 0.5).astype(int))
final_auc = roc_auc_score(Y, oof_preds)
print(f"\nOverall Accuracy: {final_acc:.4f}")
print(f"Overall ROC AUC:  {final_auc:.4f}")



# Save to CSV
submission = pd.DataFrame({
    "id": test_id,     # replace with your test IDs if available
    "prediction": test_preds
})
submission.to_csv("submission.csv", index=False)

print("\n✅ Predictions saved to submission.csv")
# Out:
# ----- Fold 1 -----
# 0:	test: 0.7755322	best: 0.7755322 (0)	total: 23.9ms	remaining: 1m 59s
# 200:	test: 0.7939720	best: 0.7940050 (177)	total: 7.52s	remaining: 2m 59s
# 400:	test: 0.7929694	best: 0.7941045 (218)	total: 15.2s	remaining: 2m 54s
# 600:	test: 0.7919837	best: 0.7941045 (218)	total: 22.8s	remaining: 2m 46s
# 800:	test: 0.7905032	best: 0.7941045 (218)	total: 30.2s	remaining: 2m 38s
# 1000:	test: 0.7894921	best: 0.7941045 (218)	total: 37.7s	remaining: 2m 30s
# 1200:	test: 0.7880870	best: 0.7941045 (218)	total: 45.2s	remaining: 2m 23s
# 1400:	test: 0.7866257	best: 0.7941045 (218)	total: 52.5s	remaining: 2m 14s
# 1600:	test: 0.7858794	best: 0.7941045 (218)	total: 1m	remaining: 2m 7s
# 1800:	test: 0.7852002	best: 0.7941045 (218)	total: 1m 7s	remaining: 1m 59s
# 2000:	test: 0.7839992	best: 0.7941045 (218)	total: 1m 14s	remaining: 1m 51s
# 2200:	test: 0.7827738	best: 0.7941045 (218)	total: 1m 22s	remaining: 1m 44s
# 2400:	test: 0.7817413	best: 0.7941045 (218)	total: 1m 29s	remaining: 1m 36s
# 2600:	test: 0.7807244	best: 0.7941045 (218)	total: 1m 36s	remaining: 1m 29s
# 2800:	test: 0.7793818	best: 0.7941045 (218)	total: 1m 44s	remaining: 1m 21s
# 3000:	test: 0.7786552	best: 0.7941045 (218)	total: 1m 51s	remaining: 1m 14s
# 3200:	test: 0.7776548	best: 0.7941045 (218)	total: 1m 58s	remaining: 1m 6s
# 3400:	test: 0.7765694	best: 0.7941045 (218)	total: 2m 6s	remaining: 59.3s
# 3600:	test: 0.7756721	best: 0.7941045 (218)	total: 2m 13s	remaining: 51.9s
# 3800:	test: 0.7748204	best: 0.7941045 (218)	total: 2m 20s	remaining: 44.5s
# 4000:	test: 0.7743405	best: 0.7941045 (218)	total: 2m 28s	remaining: 37s
# 4200:	test: 0.7734748	best: 0.7941045 (218)	total: 2m 35s	remaining: 29.6s
# 4400:	test: 0.7726934	best: 0.7941045 (218)	total: 2m 43s	remaining: 22.2s
# 4600:	test: 0.7717966	best: 0.7941045 (218)	total: 2m 50s	remaining: 14.8s
# 4800:	test: 0.7711905	best: 0.7941045 (218)	total: 2m 57s	remaining: 7.37s
# 4999:	test: 0.7703401	best: 0.7941045 (218)	total: 3m 5s	remaining: 0us
#
# bestTest = 0.7941045106
# bestIteration = 218
#
# Shrink model to first 219 iterations.
# Fold 1 Accuracy: 0.7511, ROC AUC: 0.7941
#
# ----- Fold 2 -----
# 0:	test: 0.7703057	best: 0.7703057 (0)	total: 23.9ms	remaining: 1m 59s
# 200:	test: 0.7898879	best: 0.7898879 (200)	total: 7.31s	remaining: 2m 54s
# 400:	test: 0.7899577	best: 0.7906565 (260)	total: 14.7s	remaining: 2m 48s
# 600:	test: 0.7893413	best: 0.7906565 (260)	total: 22.1s	remaining: 2m 41s
# 800:	test: 0.7882654	best: 0.7906565 (260)	total: 29.4s	remaining: 2m 34s
# 1000:	test: 0.7866589	best: 0.7906565 (260)	total: 37s	remaining: 2m 27s
# 1200:	test: 0.7857690	best: 0.7906565 (260)	total: 44.4s	remaining: 2m 20s
# 1400:	test: 0.7850048	best: 0.7906565 (260)	total: 51.8s	remaining: 2m 13s
# 1600:	test: 0.7837470	best: 0.7906565 (260)	total: 59.2s	remaining: 2m 5s
# 1800:	test: 0.7827092	best: 0.7906565 (260)	total: 1m 6s	remaining: 1m 58s
# 2000:	test: 0.7814031	best: 0.7906565 (260)	total: 1m 13s	remaining: 1m 50s
# 2200:	test: 0.7807791	best: 0.7906565 (260)	total: 1m 21s	remaining: 1m 43s
# 2400:	test: 0.7796824	best: 0.7906565 (260)	total: 1m 28s	remaining: 1m 35s
# 2600:	test: 0.7787751	best: 0.7906565 (260)	total: 1m 36s	remaining: 1m 28s
# 3800:	test: 0.7772932	best: 0.7943166 (362)	total: 2m 20s	remaining: 44.3s
# 4000:	test: 0.7765323	best: 0.7943166 (362)	total: 2m 30s	remaining: 37.5s
# 4200:	test: 0.7759217	best: 0.7943166 (362)	total: 2m 37s	remaining: 30s
# 4400:	test: 0.7755088	best: 0.7943166 (362)	total: 2m 45s	remaining: 22.5s
# 4600:	test: 0.7747378	best: 0.7943166 (362)	total: 2m 52s	remaining: 15s
# 4800:	test: 0.7741022	best: 0.7943166 (362)	total: 2m 59s	remaining: 7.45s
# 4999:	test: 0.7736731	best: 0.7943166 (362)	total: 3m 8s	remaining: 0us
#
# bestTest = 0.7943165738
# bestIteration = 362
#
# Shrink model to first 363 iterations.
# Fold 3 Accuracy: 0.7526, ROC AUC: 0.7943
#
# ----- Fold 4 -----
# 0:	test: 0.7759192	best: 0.7759192 (0)	total: 74.9ms	remaining: 6m 14s
# 200:	test: 0.7950468	best: 0.7952068 (172)	total: 8.29s	remaining: 3m 18s
# 400:	test: 0.7942462	best: 0.7954365 (279)	total: 16.2s	remaining: 3m 6s
# 600:	test: 0.7928744	best: 0.7954365 (279)	total: 23.7s	remaining: 2m 53s
# 800:	test: 0.7906969	best: 0.7954365 (279)	total: 31.1s	remaining: 2m 42s
# 1000:	test: 0.7894171	best: 0.7954365 (279)	total: 38.6s	remaining: 2m 34s
# 1200:	test: 0.7876743	best: 0.7954365 (279)	total: 45.9s	remaining: 2m 25s
# 1400:	test: 0.7852085	best: 0.7954365 (279)	total: 53.2s	remaining: 2m 16s
# 1600:	test: 0.7836874	best: 0.7954365 (279)	total: 1m	remaining: 2m 8s
# 1800:	test: 0.7821124	best: 0.7954365 (279)	total: 1m 8s	remaining: 2m 1s
# 2000:	test: 0.7808303	best: 0.7954365 (279)	total: 1m 15s	remaining: 1m 53s
# 2200:	test: 0.7795553	best: 0.7954365 (279)	total: 1m 23s	remaining: 1m 46s
# 2400:	test: 0.7787898	best: 0.7954365 (279)	total: 1m 31s	remaining: 1m 39s
# 2600:	test: 0.7774062	best: 0.7954365 (279)	total: 1m 39s	remaining: 1m 31s
# 2800:	test: 0.7762493	best: 0.7954365 (279)	total: 1m 46s	remaining: 1m 23s
# 3000:	test: 0.7753010	best: 0.7954365 (279)	total: 1m 53s	remaining: 1m 15s
# 3200:	test: 0.7743732	best: 0.7954365 (279)	total: 2m 1s	remaining: 1m 8s
# 3400:	test: 0.7731880	best: 0.7954365 (279)	total: 2m 8s	remaining: 1m
# 3600:	test: 0.7722166	best: 0.7954365 (279)	total: 2m 16s	remaining: 52.9s
# 3800:	test: 0.7714941	best: 0.7954365 (279)	total: 2m 23s	remaining: 45.3s
# 4000:	test: 0.7703165	best: 0.7954365 (279)	total: 2m 32s	remaining: 38s
# 4200:	test: 0.7697775	best: 0.7954365 (279)	total: 2m 39s	remaining: 30.3s
# 4400:	test: 0.7690302	best: 0.7954365 (279)	total: 2m 46s	remaining: 22.7s
# 4600:	test: 0.7684495	best: 0.7954365 (279)	total: 2m 54s	remaining: 15.1s
# 4800:	test: 0.7677634	best: 0.7954365 (279)	total: 3m 1s	remaining: 7.52s
# 4999:	test: 0.7671104	best: 0.7954365 (279)	total: 3m 8s	remaining: 0us
#
# bestTest = 0.7954364679
# bestIteration = 279
#
# Shrink model to first 280 iterations.
# Fold 4 Accuracy: 0.7509, ROC AUC: 0.7954
#
# ----- Fold 5 -----
# 0:	test: 0.7668876	best: 0.7668876 (0)	total: 23.5ms	remaining: 1m 57s
# 200:	test: 0.7899582	best: 0.7901616 (168)	total: 7.47s	remaining: 2m 58s
# 400:	test: 0.7887712	best: 0.7901616 (168)	total: 14.8s	remaining: 2m 49s
# 600:	test: 0.7877176	best: 0.7901616 (168)	total: 22.1s	remaining: 2m 41s
# 800:	test: 0.7859718	best: 0.7901616 (168)	total: 31.2s	remaining: 2m 43s
# 1000:	test: 0.7850225	best: 0.7901616 (168)	total: 38.6s	remaining: 2m 34s
# 1200:	test: 0.7838211	best: 0.7901616 (168)	total: 46.2s	remaining: 2m 26s
# 1400:	test: 0.7824051	best: 0.7901616 (168)	total: 56.1s	remaining: 2m 24s
# 1600:	test: 0.7810463	best: 0.7901616 (168)	total: 1m 6s	remaining: 2m 21s
# 1800:	test: 0.7795050	best: 0.7901616 (168)	total: 1m 15s	remaining: 2m 14s
# 2000:	test: 0.7779003	best: 0.7901616 (168)	total: 1m 25s	remaining: 2m 7s
# 2200:	test: 0.7775963	best: 0.7901616 (168)	total: 1m 32s	remaining: 1m 58s
# 2400:	test: 0.7764128	best: 0.7901616 (168)	total: 1m 40s	remaining: 1m 48s
# 2600:	test: 0.7758169	best: 0.7901616 (168)	total: 1m 49s	remaining: 1m 40s
# 2800:	test: 0.7749507	best: 0.7901616 (168)	total: 1m 57s	remaining: 1m 31s
# 3000:	test: 0.7742056	best: 0.7901616 (168)	total: 2m 4s	remaining: 1m 23s
# 3200:	test: 0.7734186	best: 0.7901616 (168)	total: 2m 12s	remaining: 1m 14s
# 3400:	test: 0.7726672	best: 0.7901616 (168)	total: 2m 19s	remaining: 1m 5s
# 3600:	test: 0.7722240	best: 0.7901616 (168)	total: 2m 27s	remaining: 57.2s
# 3800:	test: 0.7717948	best: 0.7901616 (168)	total: 2m 34s	remaining: 48.8s
# 4000:	test: 0.7709637	best: 0.7901616 (168)	total: 2m 42s	remaining: 40.5s
# 4200:	test: 0.7706776	best: 0.7901616 (168)	total: 2m 49s	remaining: 32.2s
# 4400:	test: 0.7699060	best: 0.7901616 (168)	total: 2m 57s	remaining: 24.2s
# 4600:	test: 0.7693497	best: 0.7901616 (168)	total: 3m 11s	remaining: 16.6s
# 4800:	test: 0.7684902	best: 0.7901616 (168)	total: 3m 20s	remaining: 8.33s
# 4999:	test: 0.7678543	best: 0.7901616 (168)	total: 3m 30s	remaining: 0us
#
# bestTest = 0.7901615555
# bestIteration = 168
#
# Shrink model to first 169 iterations.
# Fold 5 Accuracy: 0.7500, ROC AUC: 0.7902
#
# Overall Accuracy: 0.7518
# Overall ROC AUC:  0.7928
#
# ✅ Predictions saved to submission.csv
